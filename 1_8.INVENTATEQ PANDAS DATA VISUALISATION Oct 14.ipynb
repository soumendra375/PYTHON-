# %%
import numpy as np 
import pandas as pd

# %%
data = pd.read_csv('C:\\Users\\Parul\\Desktop\\DATASETS\\Pandas master\\pandas-master\\iris.data',names=['sepal length in cm','sepal width in cm','petal length in cm','petal width in cm', 'class'])
data.head(5)
#print(data.tail())
# Out:
#    sepal length in cm  sepal width in cm  petal length in cm  \
# 0                 5.1                3.5                 1.4
# 1                 4.9                3.0                 1.4
# 2                 4.7                3.2                 1.3
# 3                 4.6                3.1                 1.5
# 4                 5.0                3.6                 1.4
#
#    petal width in cm        class
# 0                0.2  Iris-setosa
# 1                0.2  Iris-setosa
# 2                0.2  Iris-setosa
# 3                0.2  Iris-setosa
# 4                0.2  Iris-setosa

# %%
# Matplotlib are used for data visualistaion - seaborn, plotly, bokeh
#from matplotlib import pyplot as plt
import matplotlib.pyplot as plt

# %%
x = [1,2,3]
y = [4,5,2]
plt.plot(x,y)

# %%
x = [1,2,3]
y = [4,5,2]
plt.plot(x,y)
plt.title('line graph')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.show()

# %%
x1 = [1,2,3]
y1 = [4,5,2]
x2 = [6,7,8]
y2 = [9,10,7]
plt.plot(x1,y1,label='first',color='r',linewidth=5)
plt.plot(x2,y2,label='second',color='m',linewidth=5)
plt.title('style graph')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.legend()
plt.grid(True,color='lightblue')
plt.show()
