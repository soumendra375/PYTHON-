# %%
import seaborn as sb

# %%
# to get dataset names
sb.get_dataset_names()
# Out:
# C:\Users\Parul\Anaconda3\lib\site-packages\seaborn\utils.py:376: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 376 of the file C:\Users\Parul\Anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'iris',
#  'mpg',
#  'planets',
#  'tips',
#  'titanic']

# %%
dataset = sb.load_dataset('iris')
print(dataset.shape)
dataset.head()
# Out:
# (150, 5)
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
dataset = sb.load_dataset('iris')
print(dataset.shape)
dataset.head()
# Out:
# (150, 5)
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
import pandas as pd
pd.unique(dataset['species'])
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
import pandas as pd
pd.unique(dataset['species'])
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sb.distplot(dataset['petal_length'])

# %%
sb.distplot(dataset['petal_length'],hist=False) # displot is a enhancement o a histgram

# %%
sb.distplot(dataset['petal_length'],kde=False)# kde - kernal density estimation

# %%
sb.distplot(dataset['petal_length'],kde=False)

# %%
# to check the correlation between petal length and petal width kde- kernal density estimation
sb.set_palette('winter')
sb.scatterplot(dataset['petal_length'],dataset['petal_width'])

# %%
sb.set_palette('winter')
sb.scatterplot(dataset['petal_length'],dataset['petal_width'])

# %%
#Pair plot
#hue adding granularity or category
#sb.pairplot(dataset,hue = 'species', diag_kind = "kde",kind = "scatter",palette = "husl")
#sb.pairplot(dataset,hue = 'species', diag_kind = "kde",kind = "scatter",palette = "winter")
#sb.pairplot(dataset,hue = 'species', diag_kind = "kde",kind = "scatter",palette = "spring")
#sb.pairplot(dataset,hue = 'species', diag_kind = "kde",kind = "scatter",palette = "autumn")
sb.pairplot(dataset,hue = 'species', diag_kind = "kde",kind = "scatter",palette = "summer")

# %%
# BOXPLOT to visualize outlier

# %%
sb.boxplot(data = dataset, x = 'species', y = 'sepal_length', palette = 'husl')

# %%
sb.boxplot(data = dataset, x = 'species', y = 'sepal_length', palette = 'husl')

# %%
# to visualize outlier
sb.swarmplot(data = dataset, x = 'species', y = 'sepal_length', palette = 'husl')

# %%
dataset = sb.load_dataset('titanic')
dataset.shape
# Out:
# (891, 15)

# %%
dataset.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sb.countplot(dataset['survived'], palette = 'autumn')

# %%
sb.countplot(dataset['sex'], palette = 'autumn')

# %%
sb.countplot(dataset['sex'], hue=dataset['survived'], palette = 'spring')

# %%
import pandas as pd

# %%
#Finding the null values
sb.heatmap(pd.isnull(dataset))
